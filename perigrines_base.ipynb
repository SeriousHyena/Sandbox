# %% [markdown]
# # Perigrine Falcon Sightings.
#
# Author: Ernest Mack
#
# Date: 11/2/2019

# %% [markdown]
# # Purpose of this map format:
# Due to the speed of map generation issues with folium I am trying Matplotlib's basemep function here. It is extremely fast to generate however, the downside is that it is not interactive and not zoomable.

# %% [markdown]
# # Import required libraries and modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Read in the datafile containing coordinates of the Perigrine sightings and assign the data to a dataframe for use in our program

# %%
df = pd.read_csv(r'C:\Users\emack\Documents\Sandbox\pfunique2.csv')

# %% [markdown]
# ### Loop through the dataframe and assign the coordinates to their respective variables for use in the map implementation

# %%
lons = [] #variable for the longitudes
lats = [] #variable for latitudes
counter = 0 #a simple counter to indicate the number of lat/lon entries

for index, row in df.iterrows(): #iterate through the dataframe and get lat/lon
     # access data using column names
    #foo = (row['longitude'], row['latitude'])
    long = row['longitude']
    latt = row['latitude']
    lons.append(long) #append the coordinate to the variable
    lats.append(latt) #append the coordinate to the variable
    counter += 1 #increment the counter

# %% [markdown]
# ### Plot the basemeap and add the Perigrine sightings to the basemap

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(50,25))
map = Basemap()

map.drawcoastlines()

x, y = map(lats, lons)

map.scatter(x, y, marker='D',color='m')


plt.show()
# Out:
# C:\Users\emack\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %% [markdown]
# # Basemap with Perigrine sightings plotted.

# %%
print('There are ', counter, 'Perigrine Falcon sightings indicated on this map.')
# Out:
# There are  24248 Perigrine Falcon sightings indicated on this map.

# %% [markdown]
# ### From above we can see that there are 24,248 sightings worldwide.
